# %%
import os
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %%
root = 'G:/gong/samples_1/data/one_point/train/'

with open(os.path.join(root+'train_val.txt'), 'r') as rf:
    i=0
    for line in rf.readlines():
        data_path = line.strip()
        
        path = os.path.join(root, 'train1', data_path)
        data = sio.loadmat(path)
        u = data["u"] * 1.0
        F = data["F"] * 1.0
        u_obs = np.ones((200,200))*298
        #for ii in range(1, 200, 64):
        #    for jj in range(1,200,64):
        #        u_obs[ii,jj]=u[ii,jj]
        #u_obs[100,100]=u[100,100]
        
        
        # observsation point for component
        '''
        u_obs[100,100]=u[100,100]
        u_obs[81, 119]=u[81,119]
        u_obs[119,119]=u[119,119]
        u_obs[100,119]=u[100,119]
        u_obs[81,81]=u[81,81]
        u_obs[81,100]=u[81,100]
        u_obs[100,81]=u[100,81]
        u_obs[119,81]=u[119,81]
        u_obs[119,100]=u[119,100]
        
        u_obs[90,119]=u[90,119]
        u_obs[90,81]=u[90,81]
        u_obs[110,81]=u[110,81]
        u_obs[110,119]=u[110,119]
        u_obs[81,90]=u[81,90]
        u_obs[81,110]=u[81,110]
        u_obs[119,90]=u[119,90]
        u_obs[119,110]=u[119,110]
        
        u_obs[110,110]=u[110,110]
        u_obs[90,90]=u[90,90]
        u_obs[90,110]=u[90,110]
        u_obs[110,90]=u[110,90]
        u_obs[90,100]=u[90,100]
        u_obs[100,90]=u[100,90]
        u_obs[110,100]=u[110,100]
        u_obs[100,110]=u[100,110]        
        '''
        # observation on heat source
        for ii in range(187-11+1, 187+11-1, 7):
            for jj in range(23-20+1,23+20-1,13):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(167-13+1, 167+13-1, 8):
            for jj in range(84-13+1,84+13-1,8):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(167-16+1, 167+16-1, 10):
            for jj in range(144-16+1,144+16-1,10):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(23-10+1, 23+10-1, 6):
            for jj in range(54-30+1,54+30-1,20):
                u_obs[ii,jj]=u[ii,jj]
        
        for ii in range(55-23+1, 55+23-1, 15):
            for jj in range(123-20+1,123+20-1,13):
                u_obs[ii,jj]=u[ii,jj]
        
        u_obs[81,81]=u[81,81]
        u_obs[81,100]=u[81,100]
        u_obs[81,119]=u[81,119]
        u_obs[100,81]=u[100,81]
        u_obs[100,90]=u[100,90]
        u_obs[100,119]=u[100,119]
        u_obs[119,81]=u[119,81]
        u_obs[119,90]=u[119,90]
        u_obs[119,119]=u[119,119]
        u_obs[110,105]=u[110,105]
        u_obs[110,85]=u[110,85]
        u_obs[90,100]=u[90,100]

        u_obs[40,30]=u[40,30]
        u_obs[40,50]=u[40,50]
        u_obs[40,70]=u[40,70]
        u_obs[60,30]=u[60,30]
        u_obs[80,30]=u[80,30]
        u_obs[60,50]=u[60,50]
        u_obs[60,70]=u[60,70]
        u_obs[80,50]=u[80,50]
        u_obs[80,70]=u[80,70]
        u_obs[50,40]=u[50,40]
        u_obs[50,60]=u[50,60]
        u_obs[70,50]=u[70,50]

        u_obs[120,140]=u[120,140]
        u_obs[120,160]=u[120,160]
        u_obs[110,135]=u[110,135]
        u_obs[110,145]=u[110,145]
        u_obs[130,145]=u[130,145]
        u_obs[130,135]=u[130,135]
        u_obs[110,175]=u[110,175]
        u_obs[130,175]=u[130,175]
        u_obs[110,160]=u[110,160]
        u_obs[130,160]=u[130,160]

        # u_obs[ii,jj]=u[ii,jj]
        u_obs[95,176]=u[95,176]
        u_obs[95,156]=u[95,156]
        u_obs[80,176]=u[80,176]
        u_obs[80,156]=u[80,156]
        u_obs[55,176]=u[55,176]
        u_obs[65,176]=u[65,176]
        u_obs[55,156]=u[55,156]
        u_obs[65,156]=u[65,156]
        u_obs[60,166]=u[60,166]
        u_obs[80,166]=u[80,166]

        u_obs[130,30]=u[130,30]
        u_obs[130,50]=u[130,50]
        u_obs[150,30]=u[150,30]
        u_obs[150,50]=u[150,50]
        u_obs[130,70]=u[130,70]
        u_obs[150,70]=u[150,70]
        u_obs[140,50]=u[140,50]
        u_obs[140,70]=u[140,70]
        # u_obs[ii,jj]=u[ii,jj]
        u_obs[140,40]=u[140,40]
        u_obs[145,60]=u[145,60]
        u_obs[135,60]=u[135,60]


        '''
        for ii in range(38-12+1, 38+12-1, 9):
            for jj in range(183-12+1,183+12-1,9):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(185-10+1, 185+10-1, 6):
            for jj in range(158-10+1,158+10-1,6):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(90-15+1, 90+15-1, 12):
            for jj in range(29-15+1,29+15-1,12):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(160-13+1, 160+13-1, 10):
            for jj in range(50-13+1,50+13-1,10):
                u_obs[ii,jj]=u[ii,jj]
        
        for ii in range(145-13+1, 145+13-1, 8):
            for jj in range(177-13+1,177+13-1,8):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(72-20+1, 72+20-1, 13):
            for jj in range(67-10+1,67+10-1,6):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(42-16+1, 42+16-1, 10):
            for jj in range(131-16+1,131+16-1,10):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(93-10+1, 93+10-1, 6):
            for jj in range(159-20+1,159+20-1,13):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(120-20+1, 120+20-1, 13):
            for jj in range(110-20+1,110+20-1,13):
                u_obs[ii,jj]=u[ii,jj]

        for ii in range(44-11+1, 44+11-1, 7):
            for jj in range(28-11+1,28+11-1,7):
                u_obs[ii,jj]=u[ii,jj]

        '''
        #u_obs[100,100]=u[100,100]
        
        # observation point for boundaries
        u_obs[1,1]=u[1,1]
        u_obs[1,50]=u[1,50]
        u_obs[1,100]=u[1,100]
        u_obs[1,150]=u[1,150]
        u_obs[1,198]=u[1,198]
        u_obs[198,1]=u[198,1]
        u_obs[198,10]=u[198,10]
        u_obs[198,20]=u[198,20]
        u_obs[198,30]=u[198,30]
        u_obs[198,40]=u[198,40]
        u_obs[198,50]=u[198,50]
        u_obs[198,60]=u[198,60]
        u_obs[198,70]=u[198,70]
        u_obs[198,80]=u[198,80]
        u_obs[198,90]=u[198,90]
        u_obs[198,100]=u[198,100]
        u_obs[198,110]=u[198,110]
        u_obs[198,120]=u[198,120]
        u_obs[198,130]=u[198,130]
        u_obs[198,140]=u[198,140]
        u_obs[198,150]=u[198,150]
        u_obs[198,160]=u[198,160]
        u_obs[198,170]=u[198,170]
        u_obs[198,180]=u[198,180]
        u_obs[198,190]=u[198,190]
        u_obs[198,198]=u[198,198]
        u_obs[50,1]=u[50,1]
        u_obs[100,1]=u[100,1]
        u_obs[150,1]=u[150,1]
        u_obs[10,198]=u[10,198]
        u_obs[20,198]=u[20,198]
        u_obs[30,198]=u[30,198]
        u_obs[40,198]=u[40,198]
        u_obs[50,198]=u[50,198]
        u_obs[60,198]=u[60,198]
        u_obs[70,198]=u[70,198]
        u_obs[80,198]=u[80,198]
        u_obs[90,198]=u[90,198]
        u_obs[100,198]=u[100,198]
        u_obs[110,198]=u[110,198]
        u_obs[120,198]=u[120,198]
        u_obs[130,198]=u[130,198]
        u_obs[140,198]=u[140,198]
        u_obs[150,198]=u[150,198]
        u_obs[160,198]=u[160,198]
        u_obs[170,198]=u[170,198]
        u_obs[180,198]=u[180,198]
        u_obs[190,198]=u[190,198]  
        
        # observation point for inside holes

        u_obs[175,50]=u[175,50]
        u_obs[185,80]=u[185,80]
        u_obs[185,140]=u[185,140]
        u_obs[140,15]=u[140,15]
        u_obs[20,15]=u[20,15]
        u_obs[60,15]=u[60,15]
        u_obs[160,30]=u[160,30]
        u_obs[105,50]=u[105,50]
        u_obs[20,110]=u[20,110]
        u_obs[30,165]=u[30,165]
        u_obs[75,185]=u[75,185]
        u_obs[120,185]=u[120,185]
        u_obs[160,170]=u[160,170]
        u_obs[160,110]=u[160,110]
        u_obs[135,100]=u[135,100]
        u_obs[90,140]=u[90,140]
        u_obs[50,85]=u[50,85]

        '''
        u_obs[180,50]=u[180,50]
        u_obs[170,100]=u[170,100]
        u_obs[192,155]=u[192,155]
        u_obs[175,175]=u[175,175]
        u_obs[160,20]=u[160,20]
        u_obs[125,50]=u[125,50]
        u_obs[185,185]=u[185,185]
        u_obs[86,10]=u[86,10]
        u_obs[40,10]=u[40,10]
        u_obs[15,22]=u[15,22]
        u_obs[25,60]=u[25,60]
        u_obs[15,130]=u[15,130]
        u_obs[15,180]=u[15,180]
        u_obs[35,195]=u[35,195]
        u_obs[135,190]=u[135,190]
        u_obs[90,180]=u[90,180]
        u_obs[62,130]=u[62,130]
        u_obs[110,150]=u[110,150]
        u_obs[40,150]=u[40,150]
        '''
        #u_obs[150,100]=u[150,100]
        #u_obs[150,50]=u[150,50]
        #u_obs[150,150]=u[150,150]
        #u_obs[50,150]=u[50,150]
        #u_obs[50,100]=u[50,100]
        #u_obs[50,50]=u[50,50]
        #u_obs[100,50]=u[100,50]
        #u_obs[100,150]=u[100,150]
        sio.savemat(os.path.join(root, "train", 'Example'+str(i)+'.mat'), {'u':u, 'F':F, 'u_obs':u_obs})
        i=i+1
        print(i)
# Out:
# 7
# 16668
# 16669
# 16670
# 16671
# 16672
# 16673
# 16674
# 16675
# 16676
# 16677
# 16678
# 16679
# 16680
# 16681
# 16682
# 16683
# 16684
# 16685
# 16686
# 16687
# 16688
# 16689
# 16690
# 16691
# 16692
# 16693
# 16694
# 16695
# 16696
# 16697
# 16698
# 16699
# 16700
# 16701
# 16702
# 16703
# 16704
# 16705
# 16706
# 16707
# 16708
# 16709
# 16710
# 16711
# 16712
# 16713
# 16714
# 16715
# 16716
# 16717
# 16718
# 16719
# 16720
# 16721
# 16722
# 16723
# 16724
# 16725
# 16726
# 16727
# 16728
# 16729
# 16730
# 16731
# 16732
# 16733
# 16734
# 16735
# 16736
# 16737
# 16738
# 16739
# 16740
# 16741
# 16742
# 16743
# 16744
# 16745
# 16746
# 16747
# 16748
# 16749
# 16750
# 16751
# 16752
# 16753
# 16754
# 16755
# 16756
# 16757
# 16758
# 16759
# 16760
# 16761
# 16762
# 16763
# 16764
# 16765
# 16766
# 16767
# 16768
# 16769
# 16770
# 16771
# 16772
# 16773
# 16774
# 16775
# 16776
# 16777
# 16778
# 16779
# 16780
# 16781
# 16782
# 16783
# 16784
# 16785
# 16786
# 16787
# 16788
# 16789
# 16790
# 16791
# ...

# %%
root = 'G:/gong/samples_1/data/one_point/test/'
path = os.path.join(root, 'test', 'Example0.mat')
data = sio.loadmat(path)
print(data)
u_true = data["u"]
F = data["F"]
#xs = data['xs']
#ys = data['ys']
u_obs = data["u_obs"]

plt.figure(figsize=(15, 5))
plt.subplot(131)
im = plt.imshow(F)
#im = plt.pcolormesh(xs,ys,u_obs)
#im = plt.imshow(u_obs)
plt.colorbar(im)

plt.subplot(132)
#im = plt.pcolormesh(xs,ys,u_true,cmap='jet')
#im = plt.pcolormesh(xs,ys,u_true)
im = plt.imshow(u_obs,cmap='jet')
#im = plt.imshow(u_true)
plt.colorbar(im)

plt.subplot(133)
#im = plt.pcolormesh(xs,ys,u_true,cmap='jet')
#im = plt.pcolormesh(xs,ys,u_true)
#im = plt.imshow(u_obs)
im = plt.imshow(u_true,cmap='jet')
plt.colorbar(im)

u_true.max(), u_true.min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-67508ead934c> in <module>
#       1 root = 'G:/gong/samples_1/data/one_point/test/'
#       2 path = os.path.join(root, 'test', 'Example0.mat')
# ----> 3 data = sio.loadmat(path)
#       4 print(data)
#       5 u_true = data["u"]
#
# NameError: name 'sio' is not defined
